# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.1.0-py3-none-any.whl (958 kB)
#      |████████████████████████████████| 958 kB 5.4 MB/s
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting trio~=0.17
#   Downloading trio-0.19.0-py3-none-any.whl (356 kB)
#      |████████████████████████████████| 356 kB 62.3 MB/s
# Collecting urllib3[secure]~=1.26
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 72.9 MB/s
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting outcome
#   Downloading outcome-1.1.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.2.0)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (2021.10.8)
# Collecting pyOpenSSL>=0.14
#   Downloading pyOpenSSL-21.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.4 MB/s
# Collecting cryptography>=1.3.4
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 33.3 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (2.21)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.4 MB/s
# Installing collected packages: sniffio, outcome, h11, cryptography, async-generator, wsproto, urllib3, trio, pyOpenSSL, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.7 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed async-generator-1.10 cryptography-36.0.1 h11-0.12.0 outcome-1.1.0 pyOpenSSL-21.0.0 selenium-4.1.0 sniffio-1.2.0 trio-0.19.0 trio-websocket-0.9.2 urllib3-1.26.7 wsproto-1.0.0

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome('D:\KoreaIT\AI\AI_3\chromedriver.exe')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stdin=PIPE,
# ---> 76                                             creationflags=self.creationflags)
#      77         except TypeError:
#
# /usr/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# /usr/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1550                             err_msg += ': ' + repr(err_filename)
# -> 1551                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1552                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\KoreaIT\\AI\\AI_3\\chromedriver.exe': 'D:\\KoreaIT\\AI\\AI_3\\chromedriver.exe'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-3-2873b8d94d6d> in <module>()
# ----> 1 driver = webdriver.Chrome('D:\KoreaIT\AI\AI_3\chromedriver.exe')
#
# /usr/local/lib/python3.7/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      71                                         port, options,
#      72                                         service_args, desired_capabilities,
# ---> 73                                         service_log_path, service, keep_alive)
#
# /usr/local/lib/python3.7/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      88
#      89         self.service = service
# ---> 90         self.service.start()
#      91
#      92         try:
#
# /usr/local/lib/python3.7/dist-packages/selenium/webdriver/common/service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'D:\KoreaIT\AI\AI_3\chromedriver.exe' executable needs to be in PATH. Please see https://chromedriver.chromium.org/home

# %%
driver.get('https://www.python.org/')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-70f5d30b6bde> in <module>()
# ----> 1 driver.get('https://www.python.org/')
#
# NameError: name 'driver' is not defined

# %%
search = driver.find_element_by_id('id-search-field')
search.send_keys('lambda')
search.send_keys(Keys.RETURN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-27a0e5df93a0> in <module>()
# ----> 1 search = driver.find_element_by_id('id-search-field')
#       2 search.send_keys('lambda')
#       3 search.send_keys(Keys.RETURN)
#
# NameError: name 'driver' is not defined

# %% [markdown]
# ### 네이트 실시간 검색어
# * https://www.nate.com/

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.1-py3-none-any.whl (37 kB)
# Using legacy 'setup.py install' for bs4, since package 'wheel' is not installed.
# Installing collected packages: soupsieve, beautifulsoup4, bs4
#     Running setup.py install for bs4: started
#     Running setup.py install for bs4: finished with status 'done'
# Successfully installed beautifulsoup4-4.10.0 bs4-0.0.1 soupsieve-2.3.1
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\yongh\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome('D:\KoreaIT\AI\AI_3\chromedriver.exe')
# Out:
# C:\Users\yongh\AppData\Local\Temp/ipykernel_7456/2114758416.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:\KoreaIT\AI\AI_3\chromedriver.exe')

# %%
driver.get('https://www.nate.com/')

# %%
# 내가한거
# import requests
# link = 'https://www.nate.com/'
# request = requests.get(link)
# html = request.text
# soup = BeautifulSoup(html, 'html.parser')

# %%
# 내가 한거
# lists = []
# issues = soup.find_all('ol', class_='isKeywordList')
# for i in range(len(issues)):
#     list.append(issues[i].text.strip().split('\n')[0])

# print(lists)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7456/3398245912.py in <module>
#       2 issues = soup.find_all('ol', class_='isKeywordList')
#       3 for i in range(len(issues)):
# ----> 4     list.append(issues[i].text.strip().split('\n')[0])
#       5
#       6 print(lists)
#
# TypeError: descriptor 'append' for 'list' objects doesn't apply to a 'str' object

# %%
html = driver.page_source
soup = BeautifulSoup(html,'html.parser')
issues = soup.find_all('a', class_='ik')

# %%
for issue in issues:
    print(issue.text.split('\n')[1], end=',')
    upDown = issue.text.split('\n')[2]
    # print(upDown)
    if upDown[:2] == '상승':
        print('↑' + upDown[2:])
    elif upDown[:2] == '하락':
        print('↓' + upDown[2:])     
    elif upDown[:2] == '동일':
        print('-')
    else:
        print(upDown)
# Out:
# 김미수,-
# 학원 독서실 방역패스,-
# 두 번째 남편,↑3
# 국회 이상직 박덕흠,↓1
# 문대통령 경계실패 중대문제,↓1

# %% [markdown]
# ### 네이버 웹툰 베스트 댓글
# * https://comic.naver.com/webtoon/detail?titleId=774862&no=50&weekday=wed

# %%
driver = webdriver.Chrome('D:\KoreaIT\AI\AI_3\chromedriver.exe')
driver.get('https://comic.naver.com/comment/comment?titleId=774862&no=50')
# Out:
# C:\Users\yongh\AppData\Local\Temp/ipykernel_7456/3178335951.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:\KoreaIT\AI\AI_3\chromedriver.exe')

# %%
html = driver.page_source
soup = BeautifulSoup(html)

# %%
nicknames = soup.find_all('span', class_='u_cbox_nick_area')
best_comments = soup.find_all('span', class_='u_cbox_contents')
print('********베스트 댓글*******')
for i in range(len(nicknames)):
    print(nicknames[i].text.strip(),':',best_comments[i].text.strip())
    print('*'*80)
# Out:
# ********베스트 댓글*******
# 김민수 : 전화해 당장
# ********************************************************************************
# sky : 니들은 여기가 웹툰인걸 알고 있구나..어디까지 알고있어? 말.해.줘.ㅎㅎ
# ********************************************************************************
# 완전미녀 : 댓글들보니 여기 인싸 하나도없네...걔네는 할수도 있잖아..물론 나도 해본적은 없어
# ********************************************************************************
# sky : 널뛰기까지 했구나..나도..해보고 싶다 널뛰기..
# ********************************************************************************
# 최원영 : 여기서 끝내다니니니니ㅣ닌니ㅣㄴ니ㅣㄴ닌토요일까지 얌전히 기다리겠습니다
# ********************************************************************************
# sky : 아유 이쁘다 이뻐어
# ********************************************************************************
# 이한결 : 유미네 방닮았다
# ********************************************************************************
# KJM : 근데 문자는 오ㅑ 그렇게 한거야
# ********************************************************************************
# 바둥바둥 : 은조가 눈치를 챌 수 있는 전조작업을 안하긴 했지1. 김치받음
# 2. 게임 같이함
# 3. 직장옮겼더니 잠깐 되다가 연락끊김
# ********************************************************************************
# Jennifer : 내가 이래서 연애를 못해요... 다지나간 버스 기다리고 있더라구요 ㅠㅠ
# ********************************************************************************
# 바둥바둥 : 좌심이 우심이 둘다 화들짝 하던데
# ********************************************************************************
# 미야 : 완이 관에 들어갔는데 이제 알아차리면 어쩔 ㅠ ㅠ
# ********************************************************************************
# 우산이끼 : 현재의 은조는 과거보다 미래의 은조를 닮아가고 있다! 머리스타일 등
# ********************************************************************************
# 미야 : 아니야 어제의 조는 몰랐을 가능성이 넘 많다
# ********************************************************************************
# 미야 : 은조야 니가 왜 완이 맘을 얘기해 ㅋㅋㅋㅋㅋㅋㅋㅋ
# ********************************************************************************

# %%
import time


html = driver.page_source
soup = BeautifulSoup(html)

comment_area = soup.findAll('span', {'class':'u_cbox_contents'})

print('*** 전체 댓글 ***')
for i in range(len(comment_area)):
    comment = comment_area[i].text.strip()
    print('-'*80)
    print(comment)
    
for i in range(2, 11):
    driver.find_element_by_xpath('//*[@id="cbox_module"]/div/div[7]/div/a[' + str(i) + ']').click()
    time.sleep(1)
    html = driver.page_source
    soup = BeautifulSoup(html)

    comment_area = soup.findAll('span', {'class':'u_cbox_contents'})

    for i in range(len(comment_area)):
        comment = comment_area[i].text.strip()
        print('-'*80)
        print(comment)
# Out:
# *** 전체 댓글 ***
# --------------------------------------------------------------------------------
# 한번이 아니잖아!
# --------------------------------------------------------------------------------
# 은조야…. ㅠㅠㅠㅠㅠㅠ
# --------------------------------------------------------------------------------
# 은조야 선톡 보내!!!
# --------------------------------------------------------------------------------
# 바보
# --------------------------------------------------------------------------------
# 으이구 그걸 이제 알았냐? 완이 그렇게 보내놓고? 힝..
# --------------------------------------------------------------------------------
# 어제의 조... 너어는 진짜
# 촉 좋은척 흐지므르...
# --------------------------------------------------------------------------------
# 컥 그런 오해를...  완이는 내내 기다렸다구ㅠ
# --------------------------------------------------------------------------------
# 연애는 타이밍...
# --------------------------------------------------------------------------------
# 느려..
# --------------------------------------------------------------------------------
# 아... 왜 이 타이밍에 끊어
# --------------------------------------------------------------------------------
# 이게 더 민망한데;;;
# --------------------------------------------------------------------------------
# 타이밍...
# --------------------------------------------------------------------------------
# 짝사랑한지  완이도 꽤 됐잖아! 그러면 그렇게 수치사를 했을지언정 마음은 아직도 남아있지! 수치사 다음엔 오기라는 녀석이 발동해서~ 다시 새로운 은조노트와 오답노트로 철저히 어드벤스드 클라스를 듣고 올껄?! 짝사랑이 한번 차였다고 그리 쉽게 꺼지는게 아니거든~
# --------------------------------------------------------------------------------
# 근데 저거 몇 컷인지도 알려주면 안되나..?
# --------------------------------------------------------------------------------
# 대리만족...하고 싶은 마음 ㅜㅠ
# C:\Users\yongh\AppData\Local\Temp/ipykernel_7456/1943443015.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="cbox_module"]/div/div[7]/div/a[' + str(i) + ']').click()
# --------------------------------------------------------------------------------
# 이 바보야!!! 그걸 키스 직전에 깨달았으면 얼마나 좋아!!!
# --------------------------------------------------------------------------------
# ㅇㅇ 늦었어
# --------------------------------------------------------------------------------
# 겠냐고 ㅠㅠㅋㅋㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# 당위의 연애와 사실의 연애... 사귀기로 약속한 사람만 좋아하기로하지만, 마음이란건 이리저리 날뛰는 것~ 연애하는 사람들은 다들 저러고 사는거지...
# --------------------------------------------------------------------------------
# 이미 늦었어
# --------------------------------------------------------------------------------
# 새디킴같아
# --------------------------------------------------------------------------------
# 근데 어조 넌 몰랐을 수도 있어
# --------------------------------------------------------------------------------
# 옆집 형같아 ㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# 슬프지만 죽여...
# --------------------------------------------------------------------------------
# 사랑에 자존심이어딨어? 완이한테연락해! 돌아온다귱
# --------------------------------------------------------------------------------
# 바보야 바보야
# --------------------------------------------------------------------------------
# 이미 끝났어 조완은 다시 차가운 도시남자 모드로 변경 됬다구 ㅠㅠ
# --------------------------------------------------------------------------------
# 전 둘이 안사귀고 친구로 지내면 좋겠어요 이성적 호감없을때의 케미가 좋아서 ㅋㅋ
# --------------------------------------------------------------------------------
# 하여간에 둔해 터진 곰녀라니깐
# --------------------------------------------------------------------------------
# 사랑은 타이밍
# --------------------------------------------------------------------------------
# 아니 그래서 이 정확한 눈치로 제대로 된 결론까지 와놓고 문자는 왜 그따구냐고 은조야ㅏ
# --------------------------------------------------------------------------------
# 응!!!!!
# --------------------------------------------------------------------------------
# 베댓 뺏은걸로 새로운 베댓 4개 창출ㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# 아 뭐냐고~~~~~~~~~!~!
# --------------------------------------------------------------------------------
# 악 완이 이미 사망했어
# --------------------------------------------------------------------------------
# 폐기물 웹툰 😹😹
# --------------------------------------------------------------------------------
# 망했어
# --------------------------------------------------------------------------------
# 지금이라도 "자니"날려
# --------------------------------------------------------------------------------
# 근데 은조 이미 사귄다 아님?
# --------------------------------------------------------------------------------
# 이미 지나갔는데...ㅠ
# --------------------------------------------------------------------------------
# 정말 총체적 난국이다
# --------------------------------------------------------------------------------
# 끝났는데 뭘 나 진짜 좋아하나? ㅇㅈR해 ㅋㅋㅋ
# --------------------------------------------------------------------------------
# 에헿에헿에헿헿ㅎ헿 입꼬리야. 내려가. 빨리!!  입꼬리:에헤헤헤헷ㅆ셋ㅅ헿ㅎ헿ㅎ헤!!!!
# --------------------------------------------------------------------------------
# 니가ㅜ몰ㅜ아러
# --------------------------------------------------------------------------------
# 그런데 우리가 어제의 조에게 너무 점수를 후하게 주는거 아니야? 저 남방을 입고있는 어제의 조가 완이 심정을 알만한 민감한 인물이었나? ㅋㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# 대기업의 횡포 ㅠㅠ
# --------------------------------------------------------------------------------
# 이컷 너무 귀엽다.. 어린이 만화같아
# --------------------------------------------------------------------------------
# 네
# --------------------------------------------------------------------------------
# 이동건 작가님 실물 한번 보고싶어요 천재 아니세요?? 이런 구성 너무 참신해
# --------------------------------------------------------------------------------
# 으이구
# --------------------------------------------------------------------------------
# 인생사 타이밍 에효 근데 또 이렇게 끝나지 않을 수도 있으니까
# 기대 쫌 해보겠으
# --------------------------------------------------------------------------------
# 160번째 댓글달성
# --------------------------------------------------------------------------------
# 아니.. 키스한거보면 벌써 답 나왔지...
# --------------------------------------------------------------------------------
# 조완 머리 초승달인줄
# --------------------------------------------------------------------------------
# 무계획... 오히려 과거가 더 순간적이고 충동적이었네...ㅋㅋㅋ
# --------------------------------------------------------------------------------
# 이러니까 내일의 조한테만 반짝이 뿌려주잖아 어제의 조야
# --------------------------------------------------------------------------------
# 우와... 역시 무빙건 작가님 정말 개쩐다고 이 감정선이나 곱씹고 하는 입체적 묘사가
# --------------------------------------------------------------------------------
# 끄아아아아얼앨어웅ㄹ러유롤
# --------------------------------------------------------------------------------
# 아니 근데 이 컷 완이 왜 라바 닮았..ㅋㅋㅋㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# 니가 몰 아라!! ٩(๑`^´๑)۶
# --------------------------------------------------------------------------------
# 유미 옷 보니까 자꾸 연어 먹고 싶네
# --------------------------------------------------------------------------------
# 작가님 하도 색이 쨍하다 멍든 것 같다 그래서 각 잡고 그려왔넹요..
# --------------------------------------------------------------------------------
# 아무렇지 않아서 더 슬펐는데요
# --------------------------------------------------------------------------------
# ↓↓그래서 애인을 사귀어 보셨다?
# --------------------------------------------------------------------------------
# 제발 둘이 지금 만나서 키스하면 안될까
# --------------------------------------------------------------------------------
# 인생은 타이밍
# --------------------------------------------------------------------------------
# 타이밍 머선 일이냐구.....ㅠㅜㅜ주 이미 늦었어.... 은조야ㅠㅜㅜ
# --------------------------------------------------------------------------------
# 베댓 실직 ㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# 은조 위컷 아래컷 머리스타일이 다르네?
# --------------------------------------------------------------------------------
# 밀어내는  은조 왜케 청순 귀염 부끄 한데ㅋㅋㅋ
# --------------------------------------------------------------------------------
# 그래해...
# --------------------------------------------------------------------------------
# 은조개웃기다고 진짜...앜ㅋㅋ
# --------------------------------------------------------------------------------
# 어
# --------------------------------------------------------------------------------
# 네
# --------------------------------------------------------------------------------
# 넌 몰라 바보야
# --------------------------------------------------------------------------------
# 니가 몰알아ㅜ
# --------------------------------------------------------------------------------
# 완이...삼가 고인의 명복을..💐
# --------------------------------------------------------------------------------
# 코가 안경에 걸렷눈데 진입 불가 아니얏?ㅠㅠ
# --------------------------------------------------------------------------------
# 언니 머시써!!!!!!!ㅠㅠ 개간지ㅠㅠㅠ
# --------------------------------------------------------------------------------
# 흐엉어ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ
# --------------------------------------------------------------------------------
# 몬소리얕ㅋㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# 이게 뭐라고라닠ㅋㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# 너무 느리네 ㅋㅋ 그걸 이제서야 고민한다고? ㅋㅋ 그낭 키갈 한번 하고 그 다음에 확인해봐도 늦지 않은데 ㅋㅋ 멍청하긴
# --------------------------------------------------------------------------------
# 폐기물 웹툰 😬
# --------------------------------------------------------------------------------
# 뿡
# --------------------------------------------------------------------------------
# 어
# --------------------------------------------------------------------------------
# 시판 나 가타
# --------------------------------------------------------------------------------
# 집 진짜 좋다
# --------------------------------------------------------------------------------
# 저런..저도 지금신랑이랑 사귀기전에한번도 날 좋아한다는 느낌을 받은적이 없어서 사귀면서도 좋아서 사귀는건지 외로워서사귀는건지 계속 확인했엏는데ㅠㅠ
# --------------------------------------------------------------------------------
# 미친
# --------------------------------------------------------------------------------
# ㅠㅠ
# --------------------------------------------------------------------------------
# 버스 떠났어, 이 여자야.
# --------------------------------------------------------------------------------
# 아 이거 겁나 웃기넼ㅋㅋㅌㅋㅋ
# --------------------------------------------------------------------------------
# 늗엇어!! ㅋㅋㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# 진짜 한번이면 기억도 안나겠지만 이미 인식할 정도로 꽤 많았던거겠지
# --------------------------------------------------------------------------------
# 그래
# --------------------------------------------------------------------------------
# 끄앜ㅋㅋㅋㅋㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# 왘ㅋㅋ
# --------------------------------------------------------------------------------
# 저어기 그 옆동네 경우 생각나넹 ㅎㅎㅎ
# --------------------------------------------------------------------------------
# 우와 이렇게 빨리 알아챈거야? 역시 눈치 크으~
# --------------------------------------------------------------------------------
# 이제 알았냐 으이구
# --------------------------------------------------------------------------------
# 인생은 타이밍 ㅠㅠㅠ
# --------------------------------------------------------------------------------
# 아니ㅠㅋㅋㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# 정답! 언니 근데 이미 완은 반 죽은 상태야
# --------------------------------------------------------------------------------
# 부럽다..
# --------------------------------------------------------------------------------
# 그정도였는데도 너가 몰랐어..
# --------------------------------------------------------------------------------
# 용의자 심문하는거 같다 ㅋㅋㅋ
# --------------------------------------------------------------------------------
# 순간적이면 안됨? 사랑에 계획서가 필수임?
# --------------------------------------------------------------------------------
# 버스떠난뒤에 쇼해봐야 안돌아온다
# --------------------------------------------------------------------------------
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# ㅋㅋㅋㅋㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# ㅁㅍㅁㅊㅁㅊㅁㅊ
# --------------------------------------------------------------------------------
# 깨닫는게 너무 늦은거 아니냐구~~!!! ㅠㅠ
# --------------------------------------------------------------------------------
# 조완 미쳤네 진짜..
# --------------------------------------------------------------------------------
# ㅋㄱㄱㄱ아개웃겨 작가혼자서 다 함ㅋㄱㄱㄱㄱㄱㄱㄱ ㅋㄱㄱㅋ
# --------------------------------------------------------------------------------
# 내남친ㅋㄱㄱㄱㅋㄲ
# --------------------------------------------------------------------------------
# 이미 민망했는ㄷ데요..
# --------------------------------------------------------------------------------
# 아니 저걸 몰랏다고?
# --------------------------------------------------------------------------------
# 이게 현실 사랑이지 타이밍 안맞는거
# --------------------------------------------------------------------------------
# 응.
# --------------------------------------------------------------------------------
# 내가 다 조완 빙의해서 민망민망하네 어우 낯뜨거워...ㅎㅎ
# --------------------------------------------------------------------------------
# 드디어 멍이 빠졌어
# --------------------------------------------------------------------------------
# 그럴리가!ㅋㅋㅋㅋㅋㅋ
# --------------------------------------------------------------------------------
# 응~
# --------------------------------------------------------------------------------
# 부담스럽지않게하기위해 저런식의 가벼운느낌을 즈ㅡ는 오답노트가 다시오답이되고ㅜㅜ
# --------------------------------------------------------------------------------
# 여전히 은조는 과거의 조가 더 강하구나..
# --------------------------------------------------------------------------------
# 근데나같아도 저리생각하겠음ㅋㅋㅋ 존잘완벽남이 갑자기 저러면 믿기지않아서 그냥 얘는 스킨쉽같은거 자연스럽게 하고다니나..?할듣
# --------------------------------------------------------------------------------
# 늦었다 그냥자라
# --------------------------------------------------------------------------------
# 과거의 조완에게 현재의 은조가 물어보는 닥터스트레인지같은 상황
# --------------------------------------------------------------------------------
# 그걸 이제 알았냐~🎵 뒷북 터지겠구나~🎶
# --------------------------------------------------------------------------------
# 그래 난 저거 진작에 눈치챘다고 후욱후욱
# --------------------------------------------------------------------------------
# ㅋ
# --------------------------------------------------------------------------------
# 전화해 당장
# --------------------------------------------------------------------------------
# 니들은 여기가 웹툰인걸 알고 있구나..어디까지 알고있어? 말.해.줘.ㅎㅎ
# --------------------------------------------------------------------------------
# 댓글들보니 여기 인싸 하나도없네...걔네는 할수도 있잖아..물론 나도 해본적은 없어
# --------------------------------------------------------------------------------
# 널뛰기까지 했구나..나도..해보고 싶다 널뛰기..
# --------------------------------------------------------------------------------
# 여기서 끝내다니니니니ㅣ닌니ㅣㄴ니ㅣㄴ닌토요일까지 얌전히 기다리겠습니다
# --------------------------------------------------------------------------------
# 아유 이쁘다 이뻐어
# --------------------------------------------------------------------------------
# 유미네 방닮았다
# --------------------------------------------------------------------------------
# 근데 문자는 오ㅑ 그렇게 한거야
# --------------------------------------------------------------------------------
# 은조가 눈치를 챌 수 있는 전조작업을 안하긴 했지1. 김치받음
# 2. 게임 같이함
# 3. 직장옮겼더니 잠깐 되다가 연락끊김
# --------------------------------------------------------------------------------
# 내가 이래서 연애를 못해요... 다지나간 버스 기다리고 있더라구요 ㅠㅠ
# --------------------------------------------------------------------------------
# 좌심이 우심이 둘다 화들짝 하던데
# --------------------------------------------------------------------------------
# 완이 관에 들어갔는데 이제 알아차리면 어쩔 ㅠ ㅠ
# --------------------------------------------------------------------------------
# 현재의 은조는 과거보다 미래의 은조를 닮아가고 있다! 머리스타일 등
# --------------------------------------------------------------------------------
# 아니야 어제의 조는 몰랐을 가능성이 넘 많다
# --------------------------------------------------------------------------------
# 은조야 니가 왜 완이 맘을 얘기해 ㅋㅋㅋㅋㅋㅋㅋㅋ
