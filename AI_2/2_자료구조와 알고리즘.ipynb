# %% [markdown]
# # **1. 자료구조**

# %% [markdown]
# * 용어 : 자료구조 data structure
# * 대량의 데이터를 효율적으로 관리할 수 있는 데이터의 구조를 의미
# * 코드상에서 효율적으로 데이터를 처리하기 위해, 데이터의 특성에 따라 체계적으로 구조화해야함

# %% [markdown]
# ### 1-1. 대표적인 자료구조

# %% [markdown]
# * 배열, 스택, 링크드리스트, 해쉬테이블, 힙 등...

# %% [markdown]
# # **2. 알고리즘**

# %% [markdown]
# * 용어 : 알고리즘, algorithm
# * 어떤 문제를 풀기 위한 절차 및 방법
# * 어떤 문제에 대해 특정한 "입력"을 넣으면 원하는 "출력"을 얻을 수 있도록 만드는 프로그래밍

# %% [markdown]
# # **3. 자료구조와 알고리즘이 중요한 이유**

# %% [markdown]
# > 어떤 자료구조와 알고리즘을 쓰느냐에 따라 프로그램의 성능의 차이가 많음

# %% [markdown]
# # **4. 파이썬을 활용한 자료구조와 알고리즘**

# %% [markdown]
# * 어떤 언어로든 자료구조와 알고리즘은 익할 수 있음
# * 예전에는 C언어 또는 C++로만 작성하도록 하는 경우가 많았음
# * 최근에는 언어로 인한 제약/평가는 없어짐
# * 가장 쉽고 빠르게 자료구조/알고리즘을 익힐 수 있는 언어 -> 파이썬
